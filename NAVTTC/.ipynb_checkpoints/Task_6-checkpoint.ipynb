# %%
import cmath

# %%
num = 1+2j

# %%
# num = eval(input("Enter number: "))
# Out:
# Enter number:  2

# %%
num_sqrt = cmath.sqrt(num)

# %%
print("The square of {0} is {1:0.3f}+{2:0.3f}j".format(num,num_sqrt.real,num_sqrt.imag))
# Out:
# The square of 2 is 1.414+0.000j

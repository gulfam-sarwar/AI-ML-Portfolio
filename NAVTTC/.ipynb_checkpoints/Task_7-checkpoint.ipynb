# %%
celsius = 37.5
fahrenheit = (celsius * 1.8) + 32

print("%0.1f degree celsius is equal to %0.1f degree fahrenehit " %(celsius, fahrenheit))
# Out:
# 37.5 degree celsius is equal to 99.5 degree fahrenehit

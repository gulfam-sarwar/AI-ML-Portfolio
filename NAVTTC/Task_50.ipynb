# %% [markdown]
# ## Machine Learning - Standard Deviation

# %%
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
x = numpy.var(speed)

print(x)
# Out:
# 0.8163265306122449

# %%
x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513
